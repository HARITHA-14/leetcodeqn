# %% [markdown]
# <a href="https://colab.research.google.com/github/HARITHA-14/leetcodeqn/blob/main/find_the_difference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Find the Difference
"""You are given two strings s and t.

String t is generated by random shuffling string s and then add one more letter at a random position.

Return the letter that was added to t."""
# Out:
# 'You are given two strings s and t.\n\nString t is generated by random shuffling string s and then add one more letter at a random position.\n\nReturn the letter that was added to t.'

# %%
class Solution:
    def findTheDifference(self, s: str, t: str) -> str:
        for i in range(len(t)+1):
            if t[i] not in s:
                    return t[i]

# %%
#approach:
"""To find the differnce in charcters of the given two strings.First we create an itear variable which iterates through all the charcters of the string and we
use a bitwise operator to check whether each character of string"t" is present in "S",if not return the character that is not common to both the strings."""
# Out:
# 'To find the differnce in charcters of the given two strings.First we create an itear variable which iterates through all the charcters of the string and we \nuse a bitwise operator to check whether each character of string"t" is present in "S",if not return the character that is not common to both the strings.'
